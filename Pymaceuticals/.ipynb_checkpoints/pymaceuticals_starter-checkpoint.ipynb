# %% [markdown]
# ## Observations and Insights

# %% [raw]
# From analysis performed it can be infered the following:
# - Ramicane has the lowest mean and standard deviation, so it can be inferred that it is the best drug to reduce tumors
# - Ketapril has the greatest mean and standard deviation, so it can be inferred that it is the worst drug to reduce tumors
# -There is statistical evidence that shows a high correlation between the weight and the average volume of the tumor for the drug capomulin.
# - Campomulin and Ramicane have almost the same mean and standard deviation, it is recommended to perform a Two sample T-test in order to know if the means are the same or defferent.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
# Display the data table for preview
merge_df.to_csv('test.csv')
merge_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
Mouse = [len(set(merge_df['Mouse ID']))]
total_mouse={'Total Mouses': Mouse}
pd.DataFrame(total_mouse)
# Out:
#    Total Mouses
# 0           249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicates = merge_df[merge_df.duplicated(subset=['Mouse ID', 'Timepoint'])]
a = duplicates['Mouse ID'].iloc[0]
a
# Out:
# 'g989'

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse = merge_df.loc[merge_df['Mouse ID'] == a]
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_df.loc[merge_df['Mouse ID'] != a]
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
Mouse1 = [len(set(clean_df['Mouse ID']))]
total_mouse1 ={'Total Mouses': Mouse1}
pd.DataFrame(total_mouse1)
# Out:
#    Total Mouses
# 0           248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

drug_group = clean_df.groupby(['Drug Regimen'])
mean = drug_group['Tumor Volume (mm3)'].mean()
median = drug_group['Tumor Volume (mm3)'].median()
variance = drug_group['Tumor Volume (mm3)'].var()
stdv = drug_group['Tumor Volume (mm3)'].std()
sem = drug_group['Tumor Volume (mm3)'].sem()
summary = pd.DataFrame({"Mean": mean, "Median": median,"Variance": variance, "Standard Deviation": stdv,"SEM":sem})
summary
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
drug_group = clean_df.groupby(['Drug Regimen'])
mean = drug_group['Tumor Volume (mm3)'].mean()
median = drug_group['Tumor Volume (mm3)'].median()
variance = drug_group['Tumor Volume (mm3)'].var()
stdv = drug_group['Tumor Volume (mm3)'].std()
sem = drug_group['Tumor Volume (mm3)'].sem()
summary = pd.DataFrame({"Mean": mean, "Median": median,"Variance": variance, "Standard Deviation": stdv,"SEM":sem})
summary
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
Mouse_treatment = clean_df.groupby(['Drug Regimen'])
x = Mouse_treatment['Mouse ID'].nunique()
plt1 = x.plot(kind = 'bar', title = 'Total mice per drug',color = ['g','b','y','r'],width=0.8)
plt1.set_ylabel("Number of mice")
# Out:
# Text(0, 0.5, 'Number of mice')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

x1 = x.reset_index()
x_axis = x1['Drug Regimen']
y_axis = x1['Mouse ID']
plt.bar(x_axis, y_axis,color = ['g','b','y','r'],width=0.8)
plt.xticks(x_axis,rotation=90)
plt.title("Total mice per drug")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of mice")
# Out:
# Text(0, 0.5, 'Number of mice')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex = clean_df.drop_duplicates(subset = "Mouse ID", keep = 'first')
sex = sex.groupby(['Sex']).count()
labels = ['Female','Male']
plt.pie(sex['Mouse ID'], labels=labels, colors=["green","yellow"],
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Mouse sex')
# Out:
# Text(0.5, 1.0, 'Mouse sex')

# %%
#a = list(sex['Mouse ID'])
a = sex['Mouse ID'].rename('')

plt2 = a.plot(kind = 'pie',
        autopct="%1.1f%%", shadow=True, startangle=140, colors=["green","yellow"]).set_title('Mouse sex')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
Maximum_values = clean_df.loc[clean_df.groupby("Mouse ID")['Timepoint'].idxmax()]
drugs = ['Capomulin','Ramicane', 'Infubinol','Ceftamin']
filtered = []
for x in drugs:
    filtered.append(Maximum_values.loc[Maximum_values['Drug Regimen'] == x])
Maximum_values
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 463      a203    Infubinol  Female          20          23         45
# 473      a251    Infubinol  Female          21          25         45
# 483      a262      Placebo  Female          17          29         45
# 493      a275     Ceftamin  Female          20          28         45
# 500      a366     Stelasyn  Female          16          29         30
# ...       ...          ...     ...         ...         ...        ...
# 1862     z435     Propriva  Female          12          26         10
# 84       z578     Ramicane    Male          11          16         45
# 1872     z581    Infubinol  Female          24          25         45
# 1882     z795     Naftisol  Female          13          29         45
# 1892     z969     Naftisol    Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 463            67.973419                 2
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Locate the rows which contain mice on each drug and get the tumor volumes 
# add subset    
# Determine outliers using upper and lower bounds
drugs = ['Capomulin','Ramicane', 'Infubinol','Ceftamin']
full_data = {}
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for x in drugs:
    med = Maximum_values.loc[Maximum_values['Drug Regimen'] == x]
    list1 = list(med['Tumor Volume (mm3)'])
    full_data[x]= list1    
    
    quartiles = med['Tumor Volume (mm3)'].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    print(f'     ********* {x} *********')
    print(f"The lower quartile of {x} is: {round(lowerq,2)}")
    print(f"The upper quartile of {x}is: {round(upperq,2)}")
    print(f"The interquartile range of {x} is: {round(iqr,2)}")
    print(f"The the median of {x} is: {round(quartiles[0.5],2)} ")

    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {round(lower_bound,2)} could be outliers.")
    print(f"Values above {round(upper_bound,2)} could be outliers.")
    below = med.loc[med['Tumor Volume (mm3)'] < lower_bound].count() 
    above =  med.loc[med['Tumor Volume (mm3)'] > upper_bound].count()
    outliers = above['Tumor Volume (mm3)'] + below['Tumor Volume (mm3)']
    print('\x1b[1;31m'+f"   {outliers} values could be outliers."+'\x1b[0m')
    print('-------------------------------------------------')
# Out:
#      ********* Capomulin *********
# The lower quartile of Capomulin is: 32.38
# The upper quartile of Capomulinis: 40.16
# The interquartile range of Capomulin is: 7.78
# The the median of Capomulin is: 38.13
# Values below 20.7 could be outliers.
# Values above 51.83 could be outliers.
#    0 values could be outliers.
# -------------------------------------------------
#      ********* Ramicane *********
# The lower quartile of Ramicane is: 31.56
# The upper quartile of Ramicaneis: 40.66
# The interquartile range of Ramicane is: 9.1
# The the median of Ramicane is: 36.56
# Values below 17.91 could be outliers.
# Values above 54.31 could be outliers.
#    0 values could be outliers.
# -------------------------------------------------
#      ********* Infubinol *********
# The lower quartile of Infubinol is: 54.05
# The upper quartile of Infubinolis: 65.53
# The interquartile range of Infubinol is: 11.48
# The the median of Infubinol is: 60.17
# Values below 36.83 could be outliers.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
red_square = dict(markerfacecolor='r', marker='s')
w = pd.DataFrame(full_data)
w.boxplot(flierprops=red_square).set_title('Drug Regimen')
# Out:
# Text(0.5, 1.0, 'Drug Regimen')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
mouse_id = 'r554'
capomulin = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin']
mouse_data = capomulin.loc[capomulin['Mouse ID'] == mouse_id]
x_vals = mouse_data['Timepoint']
y_vals = mouse_data['Tumor Volume (mm3)']
plt.plot(x_vals,y_vals,'gs-', linewidth=2, markersize=12)
plt.title('Timepount vs. Tumor volume (Capomulin)')
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
average = capomulin.groupby('Mouse ID').mean()
x_values = average['Weight (g)']
y_values = average['Tumor Volume (mm3)']
plt.scatter(x_values,y_values,marker="o",facecolors="green", edgecolors="black", alpha=0.60)
plt.title('Mouse weight vs. Average tumor volume (Capomulin)')
plt.xlabel('Weight (g)')
plt.ylabel('Average tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values,marker="o",facecolors="green", edgecolors="black", alpha=0.60)
plt.title('Mouse weight vs. Average tumor volume (Capomulin)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,36),fontsize=15,color="blue")
plt.xlabel('Weight (g)')
plt.ylabel('Average tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between both factors is 0.84
